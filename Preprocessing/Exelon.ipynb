# %%
import pandas as pd

from datetime import datetime, timedelta
import requests

# %%
# datetime format ------> 2025-01-01T00:00:00Z

# %%
# start_datetime = 025-01-01T00:00:00Z
# end_datetime = 2025-12-31T23:59:59Z
# start_datetime = f'{datetime(2025, 1, 1)}T00:00:00Z'

# %%
url = "https://data.elexon.co.uk/bmrs/api/v1/datasets/FUELINST"

# %%
start_date = datetime(2025, 1, 1)
end_date = datetime(2025, 12, 31)

all_data = []

# %%
current_start = start_date

while current_start <= end_date:
    current_end = min(current_start + timedelta(days=6), end_date)

    params = {
        "publishDateTimeFrom": current_start.strftime("%Y-%m-%dT00:00:00Z"),
        "publishDateTimeTo": current_end.strftime("%Y-%m-%dT23:59:59Z"),
        "format": "json"
    }

    response = requests.get(url, params=params)
    response.raise_for_status()

    data = response.json()

    if "data" in data:
        all_data.extend(data["data"])

    current_start = current_end + timedelta(days=1)

df = pd.DataFrame(all_data)

# %%
df
# Out:
#           dataset           publishTime             startTime settlementDate  \
# 0        FUELINST  2025-01-07T23:55:00Z  2025-01-07T23:50:00Z     2025-01-07
# 1        FUELINST  2025-01-07T23:55:00Z  2025-01-07T23:50:00Z     2025-01-07
# 2        FUELINST  2025-01-07T23:55:00Z  2025-01-07T23:50:00Z     2025-01-07
# 3        FUELINST  2025-01-07T23:55:00Z  2025-01-07T23:50:00Z     2025-01-07
# 4        FUELINST  2025-01-07T23:55:00Z  2025-01-07T23:50:00Z     2025-01-07
# ...           ...                   ...                   ...            ...
# 2102395  FUELINST  2025-12-31T00:00:00Z  2025-12-30T23:55:00Z     2025-12-30
# 2102396  FUELINST  2025-12-31T00:00:00Z  2025-12-30T23:55:00Z     2025-12-30
# 2102397  FUELINST  2025-12-31T00:00:00Z  2025-12-30T23:55:00Z     2025-12-30
# 2102398  FUELINST  2025-12-31T00:00:00Z  2025-12-30T23:55:00Z     2025-12-30
# 2102399  FUELINST  2025-12-31T00:00:00Z  2025-12-30T23:55:00Z     2025-12-30
#
#          settlementPeriod fuelType  generation
# 0                      48  BIOMASS        1794
# 1                      48     CCGT        5616
# 2                      48     COAL           0
# 3                      48  INTELEC           0
# 4                      48    INTEW        -531
# ...                   ...      ...         ...
# 2102395                48     OCGT           0
# 2102396                48      OIL           0
# 2102397                48    OTHER         285
# 2102398                48       PS          -7
# 2102399                48     WIND        7734
#
# [2102400 rows x 7 columns]

# %%
df.to_csv("Exelon.csv", index=False)
